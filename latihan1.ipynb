# %% [markdown]
# <a href="https://colab.research.google.com/github/nrmlptr/Latihan-ML/blob/main/latihan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('sample_data/california_housing_train.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
# Normalization dalam Data Preparation

from sklearn.preprocessing import MinMaxScaler
data = [[12000000, 33], [35000000, 45], [4000000, 23], [6500000, 26], [9000000, 29]]

scaler = MinMaxScaler()
scaler.fit(data)

print(scaler.transform(data))
# Out:
# [[0.25806452 0.45454545]
#  [1.         1.        ]
#  [0.         0.        ]
#  [0.08064516 0.13636364]
#  [0.16129032 0.27272727]]

# %%
# Contoh Standardisasi dalam Data Preparation pada ML

from sklearn import preprocessing
data = [[12000000, 33], [35000000, 45], [4000000, 23], [6500000, 26], [9000000, 29]]

scaler = preprocessing.StandardScaler().fit(data)
data = scaler.transform(data)
data
# Out:
# array([[-0.11638732,  0.23521877],
#        [ 1.94277296,  1.80334389],
#        [-0.83261698, -1.07155217],
#        [-0.60879521, -0.67952089],
#        [-0.38497344, -0.28748961]])

# %%
# Training Set dan Test Set

from sklearn.model_selection import train_test_split

X_data = range(10)
y_data = range(10)

print("random_state ditentukan")
for i in range(3):
    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size = 0.3, random_state = 42)
    print(y_test)


print("random_state tidak ditentukan")
for i in range(3):
    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size = 0.3, random_state = None)
    print(y_test)
# Out:
# random_state ditentukan
# [8, 1, 5]
# [8, 1, 5]
# [8, 1, 5]
# random_state tidak ditentukan
# [2, 9, 4]
# [7, 5, 8]
# [5, 9, 4]
